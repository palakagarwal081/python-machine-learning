# %% [markdown]
# 1.Pivot Table

# %% [markdown]
# 2.Pandas Concat

# %% [markdown]
# 3.Pandas Merge

# %% [markdown]
# 4.Panda join

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = {'Country':['India','USA','Japan','China','India','USA'],
        'Year':['2010','2010','2010','2015','2015','2015'],
        'Continent':['Asia','NA','Asia','Asia','Asia','NA'],
        'Value':[20,10,40,50,60,55]
       }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Country  Year Continent  Value
# 0   India  2010      Asia     20
# 1     USA  2010        NA     10
# 2   Japan  2010      Asia     40
# 3   China  2015      Asia     50
# 4   India  2015      Asia     60
# 5     USA  2015        NA     55

# %%
pd.pivot_table(df,index=['Year'],aggfunc='sum') # pivot_table works like groupby(it can apply for multidimension while groupby is for 2D)
# Out:
#       Value
# Year
# 2010     70
# 2015    165

# %%
pd.pivot_table(df,index=['Year'],aggfunc='mean')
# Out:
#           Value
# Year
# 2010  23.333333
# 2015  55.000000

# %%
pd.pivot_table(df,index=['Year'],aggfunc='max')
# Out:
#      Continent Country  Value
# Year
# 2010        NA     USA     40
# 2015        NA     USA     60

# %%
pd.pivot_table(df,index=['Country'],aggfunc='sum')
# Out:
#          Value
# Country
# China       50
# India       80
# Japan       40
# USA         65

# %%
pd.pivot_table(df,index=['Continent'],aggfunc='sum')
# Out:
#            Value
# Continent
# Asia         170
# NA            65

# %% [markdown]
# # Concat

# %%
# for adding different dataframe together when columns are same

# %%
people1 = {'id':[1,2,3,4],
          'name':['ab','rf','kl','ed'],
          'age':[45,25,41,30]}

people2 = {'id':[11,22,33,44],
          'name':['awb','rgf','kal','ejd'],
          'age':[35,15,40,35]}

people3 = {'id':[111,222,333,444],
          'name':['oab','rnf','kml','ecd'],
          'age':[55,75,81,50]}

# %%
df1 = pd.DataFrame(people1)
df2 = pd.DataFrame(people2)
df3 = pd.DataFrame(people3)

# %%
df1
# Out:
#    id name  age
# 0   1   ab   45
# 1   2   rf   25
# 2   3   kl   41
# 3   4   ed   30

# %%
df2
# Out:
#    id name  age
# 0  11  awb   35
# 1  22  rgf   15
# 2  33  kal   40
# 3  44  ejd   35

# %%
df3
# Out:
#     id name  age
# 0  111  oab   55
# 1  222  rnf   75
# 2  333  kml   81
# 3  444  ecd   50

# %%
pd.concat([df1,df2,df3])
# Out:
#     id name  age
# 0    1   ab   45
# 1    2   rf   25
# 2    3   kl   41
# 3    4   ed   30
# 0   11  awb   35
# 1   22  rgf   15
# 2   33  kal   40
# 3   44  ejd   35
# 0  111  oab   55
# 1  222  rnf   75
# 2  333  kml   81
# 3  444  ecd   50

# %%
pd.concat([df1,df2,df3],ignore_index = True)
# Out:
#      id name  age
# 0     1   ab   45
# 1     2   rf   25
# 2     3   kl   41
# 3     4   ed   30
# 4    11  awb   35
# 5    22  rgf   15
# 6    33  kal   40
# 7    44  ejd   35
# 8   111  oab   55
# 9   222  rnf   75
# 10  333  kml   81
# 11  444  ecd   50

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#    id name  age  id name  age   id name  age
# 0   1   ab   45  11  awb   35  111  oab   55
# 1   2   rf   25  22  rgf   15  222  rnf   75
# 2   3   kl   41  33  kal   40  333  kml   81
# 3   4   ed   30  44  ejd   35  444  ecd   50

# %% [markdown]
# # Merge

# %%
people4 = {'id':[1,2,3,4],
          'name':['ab','rf','kl','ed'],
          'age':[45,25,41,30]}

people5 = {'id':[1,2,3,4],
          'name':['ab','rf','kl','ed'],
          'sales':[535,415,540,235]}

# %%
df4 = pd.DataFrame(people4)
df5 = pd.DataFrame(people5)

# %%
df4
# Out:
#    id name  age
# 0   1   ab   45
# 1   2   rf   25
# 2   3   kl   41
# 3   4   ed   30

# %%
df5
# Out:
#    id name  sales
# 0   1   ab    535
# 1   2   rf    415
# 2   3   kl    540
# 3   4   ed    235

# %%
pd.merge(df4,df5,on=['id','name'])
# Out:
#    id name  age  sales
# 0   1   ab   45    535
# 1   2   rf   25    415
# 2   3   kl   41    540
# 3   4   ed   30    235

# %%
pd.merge(df4,df5,on=['id'])
# Out:
#    id name_x  age name_y  sales
# 0   1     ab   45     ab    535
# 1   2     rf   25     rf    415
# 2   3     kl   41     kl    540
# 3   4     ed   30     ed    235

# %% [markdown]
# # Join

# %%
people6 = {'id':[1,2,3,4],
          'name':['ab','rf','kl','ed'],
          'age':[45,25,41,30]}

people7 = {
          's_name':['b','r','l','d'],
          'ph':[123535,417415,895540,365235]}

# %%
df6 = pd.DataFrame(people6)
df7 = pd.DataFrame(people7)

# %%
df6.join(df7)
# Out:
#    id name  age s_name      ph
# 0   1   ab   45      b  123535
# 1   2   rf   25      r  417415
# 2   3   kl   41      l  895540
# 3   4   ed   30      d  365235

# %% [markdown]
# #### reading tsv csv txt files

# %%
d = pd.read_csv('myfile.csv')

# %%
d
# Out:
#        name  age  roll
# 0   'akash'   21   100
# 1  'akshat'   22   101
# 2   'sunny'   20   102
# 3   'bunny'   25   103
# 4  'ashish'   24   104

# %%
d1 = pd.read_csv('mytsv.tsv')

# %%
d1
# Out:
#      name\tage\troll
# 0   'akash'\t21\t100
# 1  'akshat'\t22\t101
# 2   'sunny'\t20\t102
# 3   'bunny'\t25\t103
# 4  'ashish'\t24\t104

# %%
d2 = pd.read_csv('mytsv.tsv',sep='\t')

# %%
d2
# Out:
#        name  age  roll
# 0   'akash'   21   100
# 1  'akshat'   22   101
# 2   'sunny'   20   102
# 3   'bunny'   25   103
# 4  'ashish'   24   104

# %%
d3 = pd.read_csv('mysemi.txt.txt')

# %%
d3
# Out:
#      name;age;roll
# 0   'akash';21;100
# 1  'akshat';22;101
# 2   'sunny';20;102
# 3   'bunny';25;103
# 4  'ashish';24;104

# %%
d3 = pd.read_csv('mysemi.txt.txt',sep = ';')

# %%
d3
# Out:
#        name  age  roll
# 0   'akash'   21   100
# 1  'akshat'   22   101
# 2   'sunny'   20   102
# 3   'bunny'   25   103
# 4  'ashish'   24   104

# %% [markdown]
# ## Creating a json file

# %%
df6
# Out:
#    id name  age
# 0   1   ab   45
# 1   2   rf   25
# 2   3   kl   41
# 3   4   ed   30

# %%
df6.to_json('myjson.json')

# %%
d4 = pd.read_json('myjson.json')

# %%
d4
# Out:
#    id name  age
# 0   1   ab   45
# 1   2   rf   25
# 2   3   kl   41
# 3   4   ed   30

# %%
df5
# Out:
#    id name  sales
# 0   1   ab    535
# 1   2   rf    415
# 2   3   kl    540
# 3   4   ed    235

# %%
df5.to_csv('mycsv.csv')

# %%
d5 = pd.read_csv('mycsv.csv')

# %%
d5
# Out:
#    Unnamed: 0  id name  sales
# 0           0   1   ab    535
# 1           1   2   rf    415
# 2           2   3   kl    540
# 3           3   4   ed    235
